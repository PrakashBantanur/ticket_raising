# %%
from warnings import filterwarnings
filterwarnings('ignore')

from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder

import pandas as pd
import numpy as np
import re
import string
import spacy

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import joblib
from tqdm import tqdm
from tqdm._tqdm_notebook import tqdm_notebook

from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

from imblearn.over_sampling import RandomOverSampler
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import cross_val_score
import pickle
import os
from sklearn import metrics

tqdm_notebook.pandas()

sns.set_style('darkgrid')

# %%
df1=pd.read_excel('C:\\Users\\a854649\\workspace\\ticket-triaging-siemens\\data\\User_Incidents_March_2021.xlsx')
df2=pd.read_excel('C:\\Users\\a854649\\workspace\\ticket-triaging-siemens\\data\\Incident + Standard Request List Report_internal_SNOW_EU.xlsx', sheet_name=0,header=1)
df3=pd.read_excel('C:\\Users\\a854649\\workspace\\ticket-triaging-siemens\\data\\SNOW_Incident + Standard Request List Report_internal_Asia.xlsx', sheet_name=0,header=1)
df4=pd.read_excel('C:\\Users\\a854649\\workspace\\ticket-triaging-siemens\\data\\User_Incidents_Aug_2021.xlsx')
df5=pd.read_excel('C:\\Users\\a854649\\workspace\\ticket-triaging-siemens\\data\\User_Incidents_May_2021.xlsx')
df6=pd.read_excel('C:\\Users\\a854649\\workspace\\ticket-triaging-siemens\\data\\User_Incidents_June_2021.xlsx')
df7=pd.read_excel('C:\\Users\\a854649\\workspace\\ticket-triaging-siemens\\data\\User_Incidents_July_2021.xlsx')
df8=pd.read_excel('C:\\Users\\a854649\\workspace\\ticket-triaging-siemens\\data\\User_Incidents_Sept_2021.xlsx')
df9=pd.read_excel('C:\\Users\\a854649\\workspace\\ticket-triaging-siemens\\data\\User_Incidents_Oct_2021.xlsx')

display(df1, df2, df3, df4, df5, df6, df7, df8, df9)
# Out:
#                  Company Ticket Number  External ID Ticket Type  \
# 0     Siemens.AMS4ER.AAE  INC020970190  INC12124999         INC
# 1     Siemens.AMS4ER.AAE  INC021033080  INC12154753         INC
# 2     Siemens.AMS4ER.AAE  INC021445790  INC12301573         INC
# 3     Siemens.AMS4ER.CEE  INC020969118  INC12123896         INC
# 4     Siemens.AMS4ER.CEE  INC020970422  INC12125208         INC
# ...                  ...           ...          ...         ...
# 1863  Siemens.AMS4ER.SWE  INC021653054  INC12395125         INC
# 1864  Siemens.AMS4ER.SWE  INC021653446  INC12395328         INC
# 1865  Siemens.AMS4ER.SWE  INC021658532          NaN         INC
# 1866  Siemens.AMS4ER.SWE  INC021659064          NaN         INC
# 1867  Siemens.AMS4ER.SWE  INC021659196          NaN         INC
#
#          Atos Subcategory 1      Atos Subcategory 2 Configuration Item  \
# 0     Local Application EU1                   SieVP                NaN
# 1                       SWP  FI-FinancialAccounting      SPIRIDON(AP0)
# 2                     FIORI                    AUTH      SPIRIDON(AP0)
# 3                       MP1       SL-SalesLogistics      SPIRIDON(MP1)
# 4                       GP1       SL-SalesLogistics      SPIRIDON(GP1)
# ...                     ...                     ...                ...
# 1863                    SWP     CS Customer Service                NaN
# 1864                    SWP       HR-HumanResources      SPIRIDON(SWP)
# 1865                    SWP      BC-BasisComponents      SPIRIDON(SWP)
# 1866                    SWP      BC-BasisComponents      SPIRIDON(SWP)
# 1867                    SWP      BC-BasisComponents      SPIRIDON(SWP)
#
#       Severity System Application  ... Division / Sector  \
# 0            4    NaN         NaN  ...               SFS
# 1            4    SWP    SPIRIDON  ...                IT
# 2            4  FIORI    SPIRIDON  ...                SI
# 3            4    MP1    SPIRIDON  ...                DI
# 4            3    GP1    SPIRIDON  ...                SI
# ...        ...    ...         ...  ...               ...
# 1863         2    SWP         NaN  ...                DI
# 1864         2    SWP    SPIRIDON  ...                DI
# 1865         4    SWP    SPIRIDON  ...           B&PS-SY
# 1866         4    SWP    SPIRIDON  ...           B&PS-SY
# 1867         4    SWP    SPIRIDON  ...           B&PS-SY
#
#                                   Site  \
# 0              SIEMS.IN.Chennai.CNI AS
# 1               SIEMS.PT.Amadora.ARA I
# 2                 SIEMS.KR.Seoul.SEL C
# 3                SIEMS.AT.Linz.LNZ NLL
# 4            SIEMS.TR.Istanbul.IST KAR
# ...                                ...
# 1863        SIEMS.IT.Milano MI.MIL VIP
# 1864        SIEMS.IT.Milano MI.MIL VIP
# 1865  ATOS.IN.Default-CITY-in-IND.INSY
# 1866  ATOS.IN.Default-CITY-in-IND.INSY
# 1867  ATOS.IN.Default-CITY-in-IND.INSY
#
#                                                Solution Primary Root Cause  \
# 0                                                   NaN                NaN
# 1                                              Resolved      Configuration
# 2     Resolved by Caller\n\ntoday, able to access vi...        Application
# 3     Resolved by Caller\n\nThank you for your help:...              Other
# 4                       Accounting records is corrected        Application
# ...                                                 ...                ...
# 1863                                                NaN                NaN
# 1864  We have rejected this ticket as it is a duplic...        Application
# 1865                                                NaN                NaN
# 1866                                                NaN                NaN
# 1867                                                NaN                NaN
#
#      Cause Code (Sub Level 1)  Incident Resolution Code  \
# 0                         NaN                       NaN
# 1                 Application             Config Change
# 2                     Failure  Information/advice given
# 3        Unable to find fault                  Repaired
# 4                 Data Issues           Amended/updated
# ...                       ...                       ...
# 1863                      NaN                       NaN
# 1864              Data Issues           No action taken
# 1865                      NaN                       NaN
# 1866                      NaN                       NaN
# 1867                      NaN                       NaN
#
#      Incident Include in Reports   Last Modified Date   tt tt_IN
# 0                            Yes     3/17/21 12:55 PM  INC   INC
# 1                            Yes      3/23/21 3:23 PM  INC   INC
# 2                            Yes      3/30/21 3:04 AM  INC   INC
# 3                            Yes  2021-12-03 07:07:00  INC   INC
# 4                            Yes     3/16/21 12:10 PM  INC   INC
# ...                          ...                  ...  ...   ...
# 1863                         Yes  2021-01-04 05:46:00  INC   INC
# 1864                         Yes      3/31/21 3:37 PM  INC   INC
# 1865                         Yes      3/31/21 9:40 PM  INC   INC
# 1866                         Yes  2021-01-04 02:25:00  INC   INC
# 1867                         Yes  2021-01-04 05:09:00  INC   INC
#
# [1868 rows x 43 columns]
#                  Company Ticket Number  External ID Ticket Type  \
# 0     Siemens.AMS4ER.AAE  INC018409152  INC11085957         INC
# 1     Siemens.AMS4ER.AAE  INC024322537  INC13502774         INC
# 2     Siemens.AMS4ER.AAE  INC024432152  INC13546467         INC
# 3     Siemens.AMS4ER.AAE  INC025459557  INC13955217         SSR
# 4     Siemens.AMS4ER.AAE  INC025574716  INC14001667         SSR
# ...                  ...           ...          ...         ...
# 8158  Siemens.AMS4ER.SWE  INC028653887  INC15171406         SSR
# 8159  Siemens.AMS4ER.SWE  INC028653911          NaN         INC
# 8160  Siemens.AMS4ER.SWE  INC028653940          NaN         INC
# 8161  Siemens.AMS4ER.SWE  INC028653964  INC15171456         SSR
# 8162  Siemens.AMS4ER.SWE  INC028653997          NaN         INC
#
#                     Atos Subcategory 1  Atos Subcategory 2  \
# 0                Local Application EU1          HR ESP Web
# 1                Local application EU2    OCC Distributori
# 2                Local application EU2    OCC Distributori
# 3                Local application EU2           Kofax SSR
# 4                Local application EU2           Kofax SSR
# ...                                ...                 ...
# 8158                       SAP SWP SRQ               Basis
# 8159                               SWP  BC-BasisComponents
# 8160                  SAP VP2 Incident  BC-BasisComponents
# 8161  SAP SWP Standard Service Request                  CO
# 8162                  SAP VP2 Incident  BC-BasisComponents
#
#          Configuration Item  Severity System            Application  ...  \
# 0             SPIRIDON(AP0)         4    NaN          SPIRIDON(AP0)  ...
# 1                       NaN         2    NaN                    NaN  ...
# 2                       NaN         4    NaN                    NaN  ...
# 3     Generic_Siemens_MMSA          4    NaN  Generic_Siemens_MMSA   ...
# 4     Generic_Siemens_MMSA          4    NaN  Generic_Siemens_MMSA   ...
# ...                     ...       ...    ...                    ...  ...
# 8158  Generic_Siemens_MMSA          4    SWP                    NaN  ...
# 8159          SPIRIDON(SWP)         4    SWP               SPIRIDON  ...
# 8160          SPIRIDON(VP2)         4    VP2               SPIRIDON  ...
# 8161  Generic_Siemens_MMSA          3    SWP                    NaN  ...
# 8162          SPIRIDON(VP2)         4    VP2               SPIRIDON  ...
#
#                              Site  \
# 0            SIEMS.IN.Pune.PUN AA
# 1            SIEMS.QA.Doha.DOH AM
# 2            SIEMS.QA.Doha.DOH AM
# 3      SIEMS.MY.Petaling jaya.PLJ
# 4           SIEMS.KW.Kuwait.KWI A
# ...                           ...
# 8158  SIEMS.FR.Saint-Denis.SDS AF
# 8159       ATOS.IN.Bangalore.INSJ
# 8160         ATOS.IN.Chennai.INAD
# 8161   SIEMS.IT.Milano MI.MIL VIP
# 8162         ATOS.IN.Chennai.INAD
#
#                                                Solution Primary Root Cause  \
# 0     No Customer Response / Aucune réponse du clien...              Other
# 1                                                   NaN                NaN
# 2                                                   NaN                NaN
# 3     Dear Danial, \n\nAs Company code  462X is  rel...         HumanError
# 4     \r\n\r\nSince there is nothing we can do from ...        Application
# ...                                                 ...                ...
# 8158                                                NaN                NaN
# 8159                                                NaN                NaN
# 8160                                                NaN                NaN
# 8161                                                NaN                NaN
# 8162                                                NaN                NaN
#
#      Cause Code (Sub Level 1)  Incident Resolution Code  \
# 0        Unable to find fault                  Repaired
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                        Atos  Information/advice given
# 4             Opened in error      Invalid or Withdrawn
# ...                       ...                       ...
# 8158                      NaN                       NaN
# 8159                      NaN                       NaN
# 8160                      NaN                       NaN
# 8161                      NaN                       NaN
# 8162                      NaN                       NaN
#
#      Has Attached Knowledge Incident Include in Reports  Last Modified Date  \
# 0                        No                         Yes 2022-02-07 02:35:45
# 1                        No                         Yes 2021-08-10 06:28:53
# 2                        No                         Yes 2021-09-01 12:00:26
# 3                        No                         Yes 2022-01-24 18:11:23
# 4                        No                         Yes 2022-01-26 23:34:03
# ...                     ...                         ...                 ...
# 8158                     No                         Yes 2022-02-15 10:59:02
# 8159                     No                         Yes 2022-02-15 11:00:19
# 8160                     No                         Yes 2022-02-15 11:02:15
# 8161                     No                         Yes 2022-02-15 11:02:27
# 8162                     No                         Yes 2022-02-15 11:04:40
#
#      Aging until 2/15/22 Days between Last Modified and 2/15/22
# 0                    483                                      8
# 1                    196                                    189
# 2                    190                                    167
# 3                    145                                     22
# 4                    140                                     20
# ...                  ...                                    ...
# 8158                   0                                      0
# 8159                   0                                      0
# 8160                   0                                      0
# 8161                   0                                      0
# 8162                   0                                      0
#
# [8163 rows x 43 columns]
#                  Company Ticket Number  External ID Ticket Type  \
# 0     Siemens.AMS4ER.AAE  INC018727393  INC11194487         INC
# 1     Siemens.AMS4ER.AAE  INC019370818  INC11455327         INC
# 2     Siemens.AMS4ER.AAE  INC019846054  INC11632717         SSR
# 3     Siemens.AMS4ER.AAE  INC021646133  INC12390542         SCR
# 4     Siemens.AMS4ER.AAE  INC023853178  INC13242221         INC
# ...                  ...           ...          ...         ...
# 2663  Siemens.AMS4ER.AAN  INC027979248  INC14909423         SCR
# 2664  Siemens.AMS4ER.AAN  INC028029103  INC14922892         SCR
# 2665  Siemens.AMS4ER.AAN  INC028032387  INC14924271         INC
# 2666  Siemens.AMS4ER.AAN  INC028035345  INC14924999         INC
# 2667  Siemens.AMS4ER.SWE  INC025954074  INC14140369         INC
#
#      Atos Subcategory 1        Atos Subcategory 2     Configuration Item  \
# 0                   AP0   FI-Financial Accounting                    NaN
# 1                   AP0            MD-Master Data                    NaN
# 2               AP0 SSR            CO-Controlling                    NaN
# 3               AP6 SCR            CO-Controlling                    NaN
# 4                   AP0        BC-BasisComponents                    NaN
# ...                 ...                       ...                    ...
# 2663        AP0 SCR AAN  PL-Procurement Logistics  Generic_Siemens_MMSA
# 2664        AP0 SCR AAN            CO-Controlling  Generic_Siemens_MMSA
# 2665            AP0 AAN  PL-Procurement Logistics  Generic_Siemens_MMSA
# 2666            AP0 AAN         PS-Project System  Generic_Siemens_MMSA
# 2667                AP0            MD-Master Data  Generic_Siemens_MMSA
#
#       Severity System Application  ... Company Code Division / Sector  \
# 0            4    AP0         NaN  ...         5675                 -
# 1            4    AP0         NaN  ...         486S               SHS
# 2            4    AP0         NaN  ...         428S               SHS
# 3            3    AP6         NaN  ...         558X               FLE
# 4            4    AP0         NaN  ...         5655               SMO
# ...        ...    ...         ...  ...          ...               ...
# 2663         4    AP0         NaN  ...         483S                IT
# 2664         4    AP0         NaN  ...         5595                DI
# 2665         4    AP0         NaN  ...         476X                IT
# 2666         4    AP0         NaN  ...         5595                SI
# 2667         4    AP0         NaN  ...         485X               GBS
#
#                              Site  \
# 0          SIEMS.PK.Karachi.KHI E
# 1     SIEMS.PK.Islamabad.ISB S 36
# 2            SIEMS.VN.Hanoi.HAN A
# 3          SIEMS.IN.Mumbai.BOM KG
# 4          SIEMS.IN.Bengaluru.BLR
# ...                           ...
# 2663         SIEMS.CO.Tenjo.TEJ B
# 2664     SIEMS.EC.Guayaquil.GYE A
# 2665         SIEMS.AR.Munro.MRU A
# 2666     SIEMS.EC.Guayaquil.GYE A
# 2667    SIEMS.IN.Bengaluru.BLR SA
#
#                                                Solution Primary Root Cause  \
# 0                                                   NaN                NaN
# 1                                                   NaN                NaN
# 2                                                   NaN                NaN
# 3                                                   NaN                NaN
# 4                                                   NaN                NaN
# ...                                                 ...                ...
# 2663                                                NaN                NaN
# 2664                                                NaN                NaN
# 2665                                                NaN                NaN
# 2666                                                NaN                NaN
# 2667  No Customer Response / Aucune réponse du clien...              Other
#
#      Cause Code (Sub Level 1) Incident Resolution Code Has Attached Knowledge  \
# 0                         NaN                      NaN                     No
# 1                         NaN                      NaN                     No
# 2                         NaN                      NaN                     No
# 3                         NaN                      NaN                     No
# 4                         NaN                      NaN                     No
# ...                       ...                      ...                    ...
# 2663                      NaN                      NaN                     No
# 2664                      NaN                      NaN                     No
# 2665                      NaN                      NaN                     No
# 2666                      NaN                      NaN                     No
# 2667     Unable to find fault                 Repaired                     No
#
#      Incident Include in Reports  Last Modified Date
# 0                            Yes 2021-07-28 23:19:02
# 1                            Yes 2020-12-08 00:42:00
# 2                            Yes 2021-08-16 07:47:22
# 3                            Yes 2021-09-06 17:41:45
# 4                            Yes 2021-07-27 04:31:39
# ...                          ...                 ...
# 2663                         Yes 2022-01-17 01:25:13
# 2664                         Yes 2022-01-17 20:57:01
# 2665                         Yes 2022-01-18 00:46:38
# 2666                         Yes 2022-01-17 23:40:33
# 2667                         Yes 2022-01-04 18:01:59
#
# [2668 rows x 41 columns]
#                 Company Ticket Number  External ID Ticket Type  \
# 0    Siemens.AMS4ER.AAE  INC024734026  INC13606364         INC
# 1    Siemens.AMS4ER.AAE  INC024881448  INC13724450         INC
# 2    Siemens.AMS4ER.AAE  INC024928860  INC13736402         INC
# 3    Siemens.AMS4ER.CEE  INC024290635  INC13482944         INC
# 4    Siemens.AMS4ER.CEE  INC024293910  INC13485964         INC
# ..                  ...           ...          ...         ...
# 951  Siemens.AMS4ER.SWE  INC024924511  INC13746625         INC
# 952  Siemens.AMS4ER.SWE  INC024924793  INC13746798         INC
# 953  Siemens.AMS4ER.SWE  INC024925024  INC13746946         INC
# 954  Siemens.AMS4ER.SWE  INC024927490  INC13748086         INC
# 955  Siemens.AMS4ER.SWE  INC024928306  INC13748356         INC
#
#     Correct Ticket Type                Atos Subcategory 1  \
# 0                   INC                               SPP
# 1                   INC  Local Application Czech Republic
# 2                   SSR                             FIORI
# 3                   INC                               MP1
# 4                   INC                               MP1
# ..                  ...                               ...
# 951                 INC                  SAP VP2 Incident
# 952                 INC                  SAP VP2 Incident
# 953                 INC                               SWP
# 954                 INC                  SAP VP2 Incident
# 955                 INC                               SWP
#
#                    Atos Subcategory 2           Configuration Item  Severity  \
# 0                  BCA-Authorizations                SPIRIDON(AP0)         4
# 1                       3i Program CZ  Readsoft application server         4
# 2                                AUTH        Generic_Siemens_MMSA          4
# 3              FI-FinancialAccounting        Generic_Siemens_MMSA          4
# 4    PMI-ProductMasterDataIntegration                SPIRIDON(MP1)         4
# ..                                ...                          ...       ...
# 951                BCA-Authorizations        Generic_Siemens_MMSA          3
# 952                BCA-Authorizations        Generic_Siemens_MMSA          3
# 953               CS Customer Service        Generic_Siemens_MMSA          2
# 954     EDI-ElectronicDataInterchange        Generic_Siemens_MMSA          4
# 955                 SL-SalesLogistics        Generic_Siemens_MMSA          4
#
#     System  ... Country Code Company Code Division / Sector  \
# 0      SPP  ...        India         5663               GBS
# 1      NaN  ...  New Zealand          NaN               SMO
# 2    FIORI  ...       Brazil          NaN                SI
# 3      MP1  ...      Austria         5220                IT
# 4      MP1  ...      Croatia         5286                DI
# ..     ...  ...          ...          ...               ...
# 951    VP2  ...        Italy         465X                SE
# 952    VP2  ...        Italy         465X                SE
# 953    SWP  ...   Luxembourg         5109                SI
# 954    VP2  ...      Belgium         9011                SE
# 955    SWP  ...     Portugal         521W               SCM
#
#                            Site  \
# 0     SIEMS.IN.Bengaluru.BLR SA
# 1      SIEMS.NZ.Auckland.AKL EL
# 2    SIEMS.BR.Jundiai-SP.JUN GA
# 3       SIEMS.AT.Vienna.VIE SIE
# 4           SIEMS.HR.Zagreb.ZAG
# ..                          ...
# 951  SIEMS.IT.Milano MI.MIL VIP
# 952  SIEMS.IT.Milano MI.MIL VIP
# 953     SIEMS.LU.Contern.KNE ER
# 954  SIEMS.BE.Beersel.HUZ G 125
# 955      SIEMS.PT.Amadora.ARA I
#
#                                               Solution Primary Root Cause  \
# 0                       Resolved by Caller\n\nResolved              Other
# 1                                                  NaN                NaN
# 2                                                  NaN                NaN
# 3    Resolved by Caller\n\nTicket can be closed. Wi...              Other
# 4                Material refreshed and it is working.        Application
# ..                                                 ...                ...
# 951                                                NaN                NaN
# 952                                                NaN                NaN
# 953                                                NaN                NaN
# 954                                                NaN                NaN
# 955                                                NaN                NaN
#
#     Cause Code (Sub Level 1) Incident Resolution Code  \
# 0       Unable to find fault                 Repaired
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3       Unable to find fault                 Repaired
# 4                Data Issues          Amended/updated
# ..                       ...                      ...
# 951                      NaN                      NaN
# 952                      NaN                      NaN
# 953                      NaN                      NaN
# 954                      NaN                      NaN
# 955                      NaN                      NaN
#
#     Incident Include in Reports  Last Modified Date
# 0                           Yes 2021-08-27 08:36:17
# 1                           Yes 2021-08-31 15:05:36
# 2                           Yes 2021-08-31 17:35:54
# 3                           Yes 2021-08-10 23:33:24
# 4                           Yes 2021-08-08 23:33:50
# ..                          ...                 ...
# 951                         Yes 2021-08-31 15:17:35
# 952                         Yes 2021-08-31 14:36:53
# 953                         Yes 2021-08-31 15:45:21
# 954                         Yes 2021-08-31 16:06:15
# 955                         Yes 2021-08-31 17:33:15
#
# [956 rows x 41 columns]
#                  Company Ticket Number  External ID Ticket Type  \
# 0     Siemens.AMS4ER.SWE  INC022697351  INC12843076         INC
# 1     Siemens.AMS4ER.SWE  INC022706269  INC12848335         INC
# 2     Siemens.AMS4ER.NWE  INC022485988  INC12755708         INC
# 3     Siemens.AMS4ER.CEE  INC022457901  INC12740310         INC
# 4     Siemens.AMS4ER.CEE  INC022353261  INC12689289         INC
# ...                  ...           ...          ...         ...
# 1048  Siemens.AMS4ER.CEE  INC022367150  INC12700889         INC
# 1049  Siemens.AMS4ER.RCA  INC022363813  INC12698894         INC
# 1050  Siemens.AMS4ER.SWE  INC022919986  INC12916652         INC
# 1051  Siemens.AMS4ER.CEE  INC022868260  INC12904632         INC
# 1052  Siemens.AMS4ER.CEE  INC022481465  INC12752923         INC
#
#          Atos Subcategory 1       Atos Subcategory 2     Configuration Item  \
# 0                       RUP  FI-Financial Accounting  Generic_Siemens_MMSA
# 1                       SWP    MM-MaterialManagement  Generic_Siemens_MMSA
# 2                       SPP    MM-MaterialManagement  Generic_Siemens_MMSA
# 3                       MP1   FI-FinancialAccounting          SPIRIDON(MP1)
# 4                     FIORI                     AUTH  Generic_Siemens_MMSA
# ...                     ...                      ...                    ...
# 1048                    GP1    MM-MaterialManagement  Generic_Siemens_MMSA
# 1049   SAP GP1 800 Incident    MM-MaterialManagement            SPRING(GP1)
# 1050                    SWP    MM-MaterialManagement  Generic_Siemens_MMSA
# 1051                    GP1       BC-BasisComponents  Generic_Siemens_MMSA
# 1052  Local application EU2              SREhelpdesk  Generic_Siemens_MMSA
#
#       Severity System            Application  ...        Country Code  \
# 0            4    RUP                    NaN  ...               Spain
# 1            3    SWP                    NaN  ...             Belgium
# 2            4    SPP                    NaN  ...              Sweden
# 3            3    MP1               SPIRIDON  ...            Slovenia
# 4            4  FIORI                    NaN  ...             Germany
# ...        ...    ...                    ...  ...                 ...
# 1048         4    GP1                    NaN  ...              Turkey
# 1049         4    GP1                 SPRING  ...  Russian Federation
# 1050         4    SWP                    NaN  ...               Spain
# 1051         3    GP1                    NaN  ...              Turkey
# 1052         3    NaN  Generic_Siemens_MMSA   ...             Germany
#
#      Company Code Division / Sector                          Site  \
# 0            5314               SFS  SIEMS.ES.Tres Cantos.TRC E 5
# 1            5101                DI          SIEMS.BE.Beersel.HUZ
# 2            5251                SI         SIEMS.SE.Solna.SOL EV
# 3            5244                IT      SIEMS.SI.Ljubljana.LJU L
# 4            418S                IT       SIEMS.DE.Muenchen.MCH P
# ...           ...               ...                           ...
# 1048         425S               SHS     SIEMS.TR.Istanbul.IST KAR
# 1049         457X                SE        SIEMS.RU.Moscow.MOW BT
# 1050         517W               SMO  SIEMS.ES.Tres Cantos.TRC E 5
# 1051         425S               SHS     SIEMS.TR.Istanbul.IST KAR
# 1052          NaN                SE      SIEMS.DE.Goerlitz.GLZ LU
#
#                                                Solution Primary Root Cause  \
# 0                                                   NaN                NaN
# 1                                                   NaN                NaN
# 2                                                   NaN                NaN
# 3                                    Done configuration        Application
# 4                            Resolved by Caller\n\ndone              Other
# ...                                                 ...                ...
# 1048                                                NaN                NaN
# 1049                Material stocks has been calculated        Application
# 1050                                                NaN                NaN
# 1051                                                NaN                NaN
# 1052  No Customer Response / Aucune réponse du clien...              Other
#
#      Cause Code (Sub Level 1) Incident Resolution Code  \
# 0                         NaN                      NaN
# 1                         NaN                      NaN
# 2                         NaN                      NaN
# 3        Configuration Issues            Config Change
# 4        Unable to find fault                 Repaired
# ...                       ...                      ...
# 1048                      NaN                      NaN
# 1049              Data Issues                 Repaired
# 1050                      NaN                      NaN
# 1051                      NaN                      NaN
# 1052     Unable to find fault                 Repaired
#
#      Incident Include in Reports  Last Modified Date
# 0                            Yes 2021-05-31 05:49:59
# 1                            Yes 2021-05-25 09:33:49
# 2                            Yes 2021-05-28 15:20:47
# 3                            Yes 2021-05-24 16:12:53
# 4                            Yes 2021-05-12 04:15:13
# ...                          ...                 ...
# 1048                         Yes 2021-05-31 08:20:22
# 1049                         Yes 2021-05-13 07:09:59
# 1050                         Yes 2021-05-31 14:08:28
# 1051                         Yes 2021-05-28 14:34:42
# 1052                         Yes 2021-05-31 15:08:16
#
# [1053 rows x 41 columns]
#                  Company Ticket Number  External ID Ticket Type  \
# 0     Siemens.AMS4ER.AAE  INC023209157  INC13043024         INC
# 1     Siemens.AMS4ER.AAE  INC023554123  INC13194067         INC
# 2     Siemens.AMS4ER.AAE  INC023571055  INC13203263         INC
# 3     Siemens.AMS4ER.CEE  INC022940536  INC12926604         INC
# 4     Siemens.AMS4ER.CEE  INC022943199  INC12928796         INC
# ...                  ...           ...          ...         ...
# 1022  Siemens.AMS4ER.SWE  INC023548758  INC13191275         INC
# 1023  Siemens.AMS4ER.SWE  INC023557785  INC13197262         INC
# 1024  Siemens.AMS4ER.SWE  INC023561396  INC13199126         INC
# 1025  Siemens.AMS4ER.SWE  INC023562174  INC13199554         INC
# 1026  Siemens.AMS4ER.SWE  INC023572092  INC13203559         INC
#
#      Revised Ticket Type     Atos Subcategory 1  \
# 0                    INC                    SWP
# 1                    INC  Local Application EU1
# 2                    INC                    SWP
# 3                    INC                    MP1
# 4                    SSR                    MP1
# ...                  ...                    ...
# 1022                 SCR                    SWP
# 1023                 INC                    SWP
# 1024                 SSR                    SWP
# 1025                 INC                    SWP
# 1026                 SSR                    SWP
#
#                  Atos Subcategory 2     Configuration Item  Severity System  \
# 0                BCA-Authorizations  Generic_Siemens_MMSA          3    SWP
# 1                        HR ESP Web  Generic_Siemens_MMSA          4    NaN
# 2                BC-BasisComponents  Generic_Siemens_MMSA          4    SWP
# 3            FI-FinancialAccounting  Generic_Siemens_MMSA          3    MP1
# 4                    Authorizations          SPIRIDON(MP1)         4    MP1
# ...                             ...                    ...       ...    ...
# 1022         FI-FinancialAccounting          SPIRIDON(SWP)         4    SWP
# 1023  EDI-ElectronicDataInterchange          SPIRIDON(SWP)         2    SWP
# 1024               ABAP-Programming  Generic_Siemens_MMSA          4    SWP
# 1025  EDI-ElectronicDataInterchange  Generic_Siemens_MMSA          3    SWP
# 1026         FI-FinancialAccounting  Generic_Siemens_MMSA          3    SWP
#
#       ...    Country Code Company Code Division / Sector  \
# 0     ...           Spain         461D                IT
# 1     ...           India          NaN               ADV
# 2     ...           Spain         461D               GBS
# 3     ...         Germany         485Q                SE
# 4     ...  Czech Republic         5975                IT
# ...   ...             ...          ...               ...
# 1022  ...        Portugal          NaN                CF
# 1023  ...         Belgium         519W               SMO
# 1024  ...        Portugal         492W                CF
# 1025  ...           Spain         5290                DI
# 1026  ...        Portugal         492W               GBS
#
#                               Site  \
# 0     SIEMS.ES.Tres Cantos.TRC E 5
# 1             SIEMS.IN.Pune.PUN AA
# 2     SIEMS.ES.Tres Cantos.TRC E 5
# 3        SIEMS.DE.Erlangen.ERL S F
# 4             SIEMS.CZ.Praha.PRG S
# ...                            ...
# 1022        SIEMS.PT.Amadora.ARA I
# 1023    SIEMS.BE.Beersel.HUZ G 125
# 1024        SIEMS.PT.Amadora.ARA I
# 1025  SIEMS.ES.Tres Cantos.TRC E 5
# 1026        SIEMS.PT.Amadora.ARA I
#
#                                                Solution Primary Root Cause  \
# 0     HI,_x000D_\n_x000D_\nrequest has been complete...           Security
# 1                                                   NaN                NaN
# 2                                                   NaN                NaN
# 3                                                   NaN                NaN
# 4     Hi Martina,\nRevoked SSO exception to login to...           Security
# ...                                                 ...                ...
# 1022                                                NaN                NaN
# 1023                                                NaN                NaN
# 1024                                                NaN                NaN
# 1025                                                 ok        Application
# 1026                                                NaN                NaN
#
#      Cause Code (Sub Level 1) Incident Resolution Code  \
# 0                  HumanError          Amended/updated
# 1                         NaN                      NaN
# 2                         NaN                      NaN
# 3                         NaN                      NaN
# 4                  KnownError          Amended/updated
# ...                       ...                      ...
# 1022                      NaN                      NaN
# 1023                      NaN                      NaN
# 1024                      NaN                      NaN
# 1025              Job.Failure                 Repaired
# 1026                      NaN                      NaN
#
#      Incident Include in Reports  Last Modified Date
# 0                            Yes 2021-06-27 23:43:12
# 1                            Yes 2021-06-30 06:03:13
# 2                            Yes 2021-06-30 19:15:33
# 3                            Yes 2021-06-29 13:36:29
# 4                            Yes 2021-06-14 10:20:53
# ...                          ...                 ...
# 1022                         Yes 2021-06-30 08:51:57
# 1023                         Yes 2021-06-30 10:38:50
# 1024                         Yes 2021-06-30 12:29:39
# 1025                         Yes 2021-06-30 12:51:30
# 1026                         Yes 2021-06-30 20:31:47
#
# [1027 rows x 41 columns]
#                 Company Ticket Number  External ID Ticket Type  \
# 0    Siemens.AMS4ER.AAE  INC023578507  INC13207160         INC
# 1    Siemens.AMS4ER.AAE  INC023688439  INC13255964         INC
# 2    Siemens.AMS4ER.AAE  INC023738613  INC13280067         INC
# 3    Siemens.AMS4ER.AAE  INC023903639  INC13349659         INC
# 4    Siemens.AMS4ER.AAE  INC024178333  INC13415516         INC
# ..                  ...           ...          ...         ...
# 963  Siemens.AMS4ER.SWE  INC024248619  INC13475036         INC
# 964  Siemens.AMS4ER.SWE  INC024248793  INC13475157         INC
# 965  Siemens.AMS4ER.SWE  INC024250936  INC13476437         INC
# 966  Siemens.AMS4ER.SWE  INC024252716  INC13443824         INC
# 967  Siemens.AMS4ER.SWE  INC024254637  INC13477996         INC
#
#     Correct Inc Type     Atos Subcategory 1      Atos Subcategory 2  \
# 0                INC                  FIORI                    AUTH
# 1                INC                    SWP  FI-FinancialAccounting
# 2                SSR                    SWP      BCA-Authorizations
# 3                INC  Local Application EU1                     SIP
# 4                INC  Local application EU2          OMS Profiforms
# ..               ...                    ...                     ...
# 963              INC                    RUP          Authorizations
# 964              INC                    SWP   MM-MaterialManagement
# 965              INC                    SWP     CS Customer Service
# 966              INC                  FIORI                     LOG
# 967              INC                    SWP       SL-SalesLogistics
#
#         Configuration Item  Severity System  ...        Country Code  \
# 0            SPIRIDON(AP0)         4  FIORI  ...  Korea, Republic of
# 1    Generic_Siemens_MMSA          3    SWP  ...            Portugal
# 2    Generic_Siemens_MMSA          4    SWP  ...            Portugal
# 3    Generic_Siemens_MMSA          4    NaN  ...           Australia
# 4    Generic_Siemens_MMSA          4    NaN  ...               India
# ..                     ...       ...    ...  ...                 ...
# 963            SAP RUP tmp         4    RUP  ...               Spain
# 964          SPIRIDON(SWP)         3    SWP  ...            Portugal
# 965  Generic_Siemens_MMSA          4    SWP  ...      United Kingdom
# 966  Generic_Siemens_MMSA          4  FIORI  ...              Brazil
# 967  Generic_Siemens_MMSA          3    SWP  ...            Portugal
#
#     Company Code Division / Sector                               Site  \
# 0            NaN               SHS               SIEMS.KR.Seoul.SEL C
# 1           461D               GBS             SIEMS.PT.Amadora.ARA I
# 2           461D                IT             SIEMS.PT.Amadora.ARA I
# 3            NaN               SHS  SIEMS.AU.Bayswater VIC.BWR MH 885
# 4            NaN                DI              SIEMS.IN.Thane.THA RD
# ..           ...               ...                                ...
# 963         5314               SFS       SIEMS.ES.Tres Cantos.TRC E 5
# 964         5140               GBS             SIEMS.PT.Amadora.ARA I
# 965          NaN               SHS             SIEMS.GB.Sudbury.SUU N
# 966         436S               SHS     SIEMS.BR.Sao Paulo-SP.SAO SP00
# 967          NaN               GBS             SIEMS.PT.Amadora.ARA I
#
#                                               Solution Primary Root Cause  \
# 0                                                  NaN              Other
# 1                                                  NaN                NaN
# 2            Resolved by Caller\n\ntHANKS pLEASE CLOSE           Security
# 3                                                  NaN                NaN
# 4                                                  NaN                NaN
# ..                                                 ...                ...
# 963  Dear User_x000D_\n _x000D_\nThe user can now e...    AccountSettings
# 964                                                NaN                NaN
# 965                                                NaN                NaN
# 966                                                NaN                NaN
# 967                                                NaN                NaN
#
#     Cause Code (Sub Level 1) Incident Resolution Code  \
# 0            Closed Remotely            Config Change
# 1                        NaN                      NaN
# 2                 KnownError          Amended/updated
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ..                       ...                      ...
# 963                   Client            Config Change
# 964                      NaN                      NaN
# 965                      NaN                      NaN
# 966                      NaN                      NaN
# 967                      NaN                      NaN
#
#     Incident Include in Reports  Last Modified Date
# 0                           Yes 2021-07-27 13:19:12
# 1                           Yes 2021-07-30 11:04:44
# 2                           Yes 2021-07-18 23:52:27
# 3                           Yes 2021-07-19 11:16:55
# 4                           Yes 2021-07-29 09:12:14
# ..                          ...                 ...
# 963                         Yes 2021-07-30 11:36:00
# 964                         Yes 2021-08-02 14:10:45
# 965                         Yes 2021-08-02 10:14:17
# 966                         Yes 2021-07-30 15:00:39
# 967                         Yes 2021-08-02 08:23:48
#
# [968 rows x 41 columns]
#                 Company Ticket Number  External ID Ticket Type  \
# 0    Siemens.AMS4ER.CEE  INC024945826  INC13757285         INC
# 1    Siemens.AMS4ER.CEE  INC024950501  INC13759780         INC
# 2    Siemens.AMS4ER.CEE  INC024951716  INC13760190         INC
# 3    Siemens.AMS4ER.CEE  INC024977951  INC13775523         INC
# 4    Siemens.AMS4ER.CEE  INC024989067  INC13780234         INC
# ..                  ...           ...          ...         ...
# 177  Siemens.AMS4ER.SWE  INC025574797  INC14001705         INC
# 178  Siemens.AMS4ER.SWE  INC025583224  INC14005110         INC
# 179  Siemens.AMS4ER.SWE  INC025586106  INC14006888         INC
# 180  Siemens.AMS4ER.SWE  INC025598803  INC14011555         INC
# 181  Siemens.AMS4ER.SWE  INC025633774  INC14027907         INC
#
#         Atos Subcategory 1      Atos Subcategory 2     Configuration Item  \
# 0                      MP1          Authorizations  Generic_Siemens_MMSA
# 1                      MP1       SL-SalesLogistics  Generic_Siemens_MMSA
# 2                      GP1  FI-FinancialAccounting  Generic_Siemens_MMSA
# 3    Local application EU2                READSOFT  Generic_Siemens_MMSA
# 4                      MP1  FI-FinancialAccounting  Generic_Siemens_MMSA
# ..                     ...                     ...                    ...
# 177                    SWP  FI-FinancialAccounting  Generic_Siemens_MMSA
# 178                    SWP   MM-MaterialManagement  Generic_Siemens_MMSA
# 179                    SWP      BCA-Authorizations  Generic_Siemens_MMSA
# 180                    SWP  FI-FinancialAccounting          SPIRIDON(SWP)
# 181                    SWP  FI-FinancialAccounting  Generic_Siemens_MMSA
#
#      Severity System            Application  ...    Country Code Company Code  \
# 0           4    MP1                    NaN  ...  Czech Republic         5975
# 1           4    MP1                    NaN  ...  Czech Republic         409S
# 2           3    GP1                    NaN  ...         Austria         443X
# 3           3    NaN  Generic_Siemens_MMSA   ...        Slovakia          NaN
# 4           2    MP1                    NaN  ...     Switzerland         487W
# ..        ...    ...                    ...  ...             ...          ...
# 177         4    SWP                    NaN  ...           Spain         401S
# 178         3    SWP                    NaN  ...           Spain         529A
# 179         4    SWP                    NaN  ...        Portugal         5240
# 180         4    SWP               SPIRIDON  ...        Portugal          NaN
# 181         3    SWP                    NaN  ...        Portugal         520W
#
#     Division / Sector                          Site  \
# 0                  IT          SIEMS.CZ.Praha.PRG S
# 1                 SHS         SIEMS.CZ.Praha.PRG BO
# 2                  CF       SIEMS.AT.Vienna.VIE SIE
# 3                 SMO     SIEMS.SK.Bratislava.BTS L
# 4                 SMO  SIEMS.CH.Wallisellen.WLN H 1
# ..                ...                           ...
# 177               SHS        SIEMS.ES.Getafe.GFE LV
# 178               SMO  SIEMS.ES.Tres Cantos.TRC E 5
# 179                IT        SIEMS.PT.Amadora.ARA I
# 180                CF        SIEMS.PT.Amadora.ARA I
# 181               GBS        SIEMS.PT.Amadora.ARA I
#
#                                               Solution Primary Root Cause  \
# 0    Hi Martina,_x000D_\nThanks for confirmation. U...           Security
# 1    Resolved by Caller\n\nThe problem was resolved...              Other
# 2      As per user's confirmation, closing this Ticket        Application
# 3                       we did the necessary changes.         Application
# 4    Resolved by Caller\n\nNo appropriate support b...              Other
# ..                                                 ...                ...
# 177                                                NaN                NaN
# 178                                                NaN                NaN
# 179  Hello Nelson,_x000D_\n_x000D_\nUsers are deact...           Security
# 180                                                NaN                NaN
# 181                                 Changes ok in  SWP        Application
#
#     Cause Code (Sub Level 1) Incident Resolution Code  \
# 0                 KnownError          Amended/updated
# 1       Unable to find fault                 Repaired
# 2       Configuration Issues            Config Change
# 3       Configuration Issues            Config Change
# 4       Unable to find fault                 Repaired
# ..                       ...                      ...
# 177                      NaN                      NaN
# 178                      NaN                      NaN
# 179               KnownError          Amended/updated
# 180                      NaN                      NaN
# 181     Configuration Issues            Config Change
#
#     Incident Include in Reports  Last Modified Date
# 0                           Yes 2021-09-08 23:34:11
# 1                           Yes 2021-09-20 23:34:07
# 2                           Yes 2021-09-19 23:34:35
# 3                           Yes 2021-09-09 23:33:40
# 4                           Yes 2021-09-13 23:33:46
# ..                          ...                 ...
# 177                         Yes 2021-09-29 07:52:31
# 178                         Yes 2021-09-29 09:37:39
# 179                         Yes 2021-09-29 11:29:56
# 180                         Yes 2021-09-29 11:44:57
# 181                         Yes 2021-09-30 10:33:58
#
# [182 rows x 40 columns]
#                  Company Ticket Number  External ID Ticket Type  \
# 0     Siemens.AMS4ER.AAE  INC024988691  INC13779912         INC
# 1     Siemens.AMS4ER.AAE  INC024990968  INC13781749         INC
# 2     Siemens.AMS4ER.AAE  INC025055673  INC13799986         INC
# 3     Siemens.AMS4ER.AAE  INC025106869  INC13825379         INC
# 4     Siemens.AMS4ER.AAE  INC025312829  INC13905355         INC
# ...                  ...           ...          ...         ...
# 1195  Siemens.AMS4ER.SWE  INC025636309  INC14028902         INC
# 1196  Siemens.AMS4ER.SWE  INC025639610  INC14030724         INC
# 1197  Siemens.AMS4ER.SWE  INC025641342  INC14031483         INC
# 1198  Siemens.AMS4ER.SWE  INC025646596  INC14033142         INC
# 1199  Siemens.AMS4ER.SWE  INC025648678  INC14033610         INC
#
#                     Atos Subcategory 1       Atos Subcategory 2  \
# 0                Local Application EU1               HR ESP Web
# 1                Local application EU2                    Kofax
# 2                Local application EU2                    Kofax
# 3                                  MP1   FI-FinancialAccounting
# 4     Local Application Czech Republic            3i Program CZ
# ...                                ...                      ...
# 1195                               SWP   FI-FinancialAccounting
# 1196                  SAP VP2 Incident       BCA-Authorizations
# 1197                               RUP  FI-Financial Accounting
# 1198                               SWP   FI-FinancialAccounting
# 1199                               SWP       BC-BasisComponents
#
#                Configuration Item  Severity System  \
# 0           Generic_Siemens_MMSA          4    NaN
# 1           Generic_Siemens_MMSA          4    NaN
# 2           Generic_Siemens_MMSA          4    NaN
# 3           Generic_Siemens_MMSA          3    MP1
# 4     Readsoft application server         1    NaN
# ...                           ...       ...    ...
# 1195                SPIRIDON(SWP)         3    SWP
# 1196        Generic_Siemens_MMSA          3    VP2
# 1197        Generic_Siemens_MMSA          4    RUP
# 1198        Generic_Siemens_MMSA          3    SWP
# 1199        Generic_Siemens_MMSA          4    SWP
#
#                       Application  ... Primary Root Cause  \
# 0           Generic_Siemens_MMSA   ...              Other
# 1           Generic_Siemens_MMSA   ...                NaN
# 2           Generic_Siemens_MMSA   ...              Other
# 3                             NaN  ...                NaN
# 4     Readsoft application server  ...              Other
# ...                           ...  ...                ...
# 1195                     SPIRIDON  ...         HumanError
# 1196                          NaN  ...           Security
# 1197                          NaN  ...                NaN
# 1198                          NaN  ...                NaN
# 1199                          NaN  ...                NaN
#
#      Cause Code (Sub Level 1) Incident Resolution Code  \
# 0        Unable to find fault                 Repaired
# 1                         NaN                      NaN
# 2        Unable to find fault                 Repaired
# 3                         NaN                      NaN
# 4        Unable to find fault                 Repaired
# ...                       ...                      ...
# 1195                   Client          Amended/updated
# 1196               HumanError          Amended/updated
# 1197                      NaN                      NaN
# 1198                      NaN                      NaN
# 1199                      NaN                      NaN
#
#      Incident Include in Reports  Last Modified Date  \
# 0                            Yes 2021-09-12 23:35:49
# 1                            Yes 2021-09-07 13:03:34
# 2                            Yes 2021-09-30 12:11:33
# 3                            Yes 2021-09-30 14:41:29
# 4                            Yes 2021-09-27 06:09:34
# ...                          ...                 ...
# 1195                         Yes 2021-09-30 13:31:02
# 1196                         Yes 2021-09-30 14:41:38
# 1197                         Yes 2021-09-30 14:38:03
# 1198                         Yes 2021-09-30 18:52:09
# 1199                         Yes 2021-09-30 20:51:44
#
#                                          processed_desc inc_probas  \
# 0     need help find new web link apply leave update...      0.645
# 1     hi would like request access kofax process dir...      0.560
# 2     user called mention issue user unable proceed ...      0.920
# 3     siemens healthcare fz llc difference zgucom re...      0.780
# 4     hi entire project unable login vdi trying logi...      0.910
# ...                                                 ...        ...
# 1195  siemens e create new internal order settlement...      0.520
# 1196  siemens energy nv sa belgium pls restore user ...      0.590
# 1197  siemens renting translated espa ol english pos...      0.600
# 1198  siemens e cannot change functional area wbs el...      0.330
# 1199  siemens spain translated spanish english colle...      0.240
#
#      predicted_ninc_tt ssr_probas scr_probas
# 0                  INC       0.00       0.00
# 1                  INC       0.00       0.00
# 2                  INC       0.00       0.00
# 3                  INC       0.00       0.00
# 4                  INC       0.00       0.00
# ...                ...        ...        ...
# 1195               INC       0.00       0.00
# 1196               INC       0.00       0.00
# 1197               INC       0.00       0.00
# 1198               SSR       0.30       0.70
# 1199               SSR       0.13       0.87
#
# [1200 rows x 45 columns]

# %%
df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9], axis=0)
df
# Out:
#                  Company Ticket Number  External ID Ticket Type  \
# 0     Siemens.AMS4ER.AAE  INC020970190  INC12124999         INC
# 1     Siemens.AMS4ER.AAE  INC021033080  INC12154753         INC
# 2     Siemens.AMS4ER.AAE  INC021445790  INC12301573         INC
# 3     Siemens.AMS4ER.CEE  INC020969118  INC12123896         INC
# 4     Siemens.AMS4ER.CEE  INC020970422  INC12125208         INC
# ...                  ...           ...          ...         ...
# 1195  Siemens.AMS4ER.SWE  INC025636309  INC14028902         INC
# 1196  Siemens.AMS4ER.SWE  INC025639610  INC14030724         INC
# 1197  Siemens.AMS4ER.SWE  INC025641342  INC14031483         INC
# 1198  Siemens.AMS4ER.SWE  INC025646596  INC14033142         INC
# 1199  Siemens.AMS4ER.SWE  INC025648678  INC14033610         INC
#
#          Atos Subcategory 1       Atos Subcategory 2     Configuration Item  \
# 0     Local Application EU1                    SieVP                    NaN
# 1                       SWP   FI-FinancialAccounting          SPIRIDON(AP0)
# 2                     FIORI                     AUTH          SPIRIDON(AP0)
# 3                       MP1        SL-SalesLogistics          SPIRIDON(MP1)
# 4                       GP1        SL-SalesLogistics          SPIRIDON(GP1)
# ...                     ...                      ...                    ...
# 1195                    SWP   FI-FinancialAccounting          SPIRIDON(SWP)
# 1196       SAP VP2 Incident       BCA-Authorizations  Generic_Siemens_MMSA
# 1197                    RUP  FI-Financial Accounting  Generic_Siemens_MMSA
# 1198                    SWP   FI-FinancialAccounting  Generic_Siemens_MMSA
# 1199                    SWP       BC-BasisComponents  Generic_Siemens_MMSA
#
#       Severity System Application  ... Aging until 2/15/22  \
# 0            4    NaN         NaN  ...                 NaN
# 1            4    SWP    SPIRIDON  ...                 NaN
# 2            4  FIORI    SPIRIDON  ...                 NaN
# 3            4    MP1    SPIRIDON  ...                 NaN
# 4            3    GP1    SPIRIDON  ...                 NaN
# ...        ...    ...         ...  ...                 ...
# 1195         3    SWP    SPIRIDON  ...                 NaN
# 1196         3    VP2         NaN  ...                 NaN
# 1197         4    RUP         NaN  ...                 NaN
# 1198         3    SWP         NaN  ...                 NaN
# 1199         4    SWP         NaN  ...                 NaN
#
#      Days between Last Modified and 2/15/22 Correct Ticket Type  \
# 0                                       NaN                 NaN
# 1                                       NaN                 NaN
# 2                                       NaN                 NaN
# 3                                       NaN                 NaN
# 4                                       NaN                 NaN
# ...                                     ...                 ...
# 1195                                    NaN                 NaN
# 1196                                    NaN                 NaN
# 1197                                    NaN                 NaN
# 1198                                    NaN                 NaN
# 1199                                    NaN                 NaN
#
#      Revised Ticket Type Correct Inc Type  \
# 0                    NaN              NaN
# 1                    NaN              NaN
# 2                    NaN              NaN
# 3                    NaN              NaN
# 4                    NaN              NaN
# ...                  ...              ...
# 1195                 NaN              NaN
# 1196                 NaN              NaN
# 1197                 NaN              NaN
# 1198                 NaN              NaN
# 1199                 NaN              NaN
#
#                                          processed_desc inc_probas  \
# 0                                                   NaN        NaN
# 1                                                   NaN        NaN
# 2                                                   NaN        NaN
# 3                                                   NaN        NaN
# 4                                                   NaN        NaN
# ...                                                 ...        ...
# 1195  siemens e create new internal order settlement...       0.52
# 1196  siemens energy nv sa belgium pls restore user ...       0.59
# 1197  siemens renting translated espa ol english pos...       0.60
# 1198  siemens e cannot change functional area wbs el...       0.33
# 1199  siemens spain translated spanish english colle...       0.24
#
#      predicted_ninc_tt ssr_probas scr_probas
# 0                  NaN        NaN        NaN
# 1                  NaN        NaN        NaN
# 2                  NaN        NaN        NaN
# 3                  NaN        NaN        NaN
# 4                  NaN        NaN        NaN
# ...                ...        ...        ...
# 1195               INC       0.00       0.00
# 1196               INC       0.00       0.00
# 1197               INC       0.00       0.00
# 1198               SSR       0.30       0.70
# 1199               SSR       0.13       0.87
#
# [18085 rows x 54 columns]

# %%
df=df[['Short Description','Description','Group']]

# %%
df.describe()
# Out:
#                  Short Description  \
# count                        18085
# unique                       16215
# top     Please create user in MyHR
# freq                            84
#
#                                               Description  \
# count                                               18085
# unique                                              17327
# top     424X - SMEE SHANGHAI,  -- Translated from Chin...
# freq                                                   21
#
#                          Group
# count                    18076
# unique                      93
# top     IN.AppsMgmt.SAP.FIN-FI
# freq                      2735

# %%
df.shape
# Out:
# (18085, 3)

# %%
display(df.loc[(df.Group == 'ZZ.ServiceDesk.ATF2.TransferSNOW')])
# Out:
#                                       Short Description  \
# 0     I am unable to get a deal booked on siesmart a...
# 30    SAP, MP1, Client 585; Not possible to close WB...
# 160               Cannot log into Dochazka (attendance)
# 469                                      gp1 connection
# 835                  SAP AP8 to PRISMA connection issue
# ...                                                 ...
# 976   After update of SAP  I can not see language op...
# 977                   Afte SAP update I can not log in.
# 980   Adobe PDF installation does not work | Origina...
# 996   A6Z00031916011 / EN1 / Vers. E | Original Text...
# 1052  "Write" access rights to managed folder (\\ ad...
#
#                                             Description  \
# 0     , Due to a BP ID 3819818 is not sync with back...
# 30    417T - Siemens Wind Power d.o.o., SAP, MP1, Cl...
# 160   , I cannot log into Attendance App since begin...
# 469   431T - Siemens Gamesa Turkey Yenilenebilir Ene...
# 835   NWE0 - Siemens NWE general, Hi,\n\nThe interfa...
# ...                                                 ...
# 976   5300 - S' Sanayi ve Ticaret, Istanbul, MM03 is...
# 977   414S - Siemens Healthcare Ltd UK, Afte SAP upd...
# 980   ,  -- Translated from Deutsch to English -- \n...
# 996   ,  -- Translated from Deutsch to English -- \n...
# 1052  ,  -- Translated from German to English -- \n ...
#
#                                  Group
# 0     ZZ.ServiceDesk.ATF2.TransferSNOW
# 30    ZZ.ServiceDesk.ATF2.TransferSNOW
# 160   ZZ.ServiceDesk.ATF2.TransferSNOW
# 469   ZZ.ServiceDesk.ATF2.TransferSNOW
# 835   ZZ.ServiceDesk.ATF2.TransferSNOW
# ...                                ...
# 976   ZZ.ServiceDesk.ATF2.TransferSNOW
# 977   ZZ.ServiceDesk.ATF2.TransferSNOW
# 980   ZZ.ServiceDesk.ATF2.TransferSNOW
# 996   ZZ.ServiceDesk.ATF2.TransferSNOW
# 1052  ZZ.ServiceDesk.ATF2.TransferSNOW
#
# [514 rows x 3 columns]

# %%
non_dupl = df[~df.duplicated()].copy()
non_dupl.shape
# Out:
# (17616, 3)

# %%
non_dupl.dropna(inplace=True)
non_dupl.shape
# Out:
# (17607, 3)

# %%
# non_dupl['Short Description'] = non_dupl['Short Description'][
#     non_dupl['Short Description'].apply(lambda x: len(x.split()) > 2) == True]
# non_dupl.shape

# %%
cnt_asgn_grps = non_dupl['Group'].value_counts()

cnt_asgn_grps.plot(kind='bar', figsize=(20, 6))
plt.show()
len(cnt_asgn_grps)
# Out:
# 93

# %%
# df = px.data.gapminder().query("continent == 'Europe' and year == 2007 and pop > 2.e6")
# fig = px.bar(df, y='pop', x='country', text_auto='.2s',
#             title="Controlled text sizes, positions and angles")
# fig.update_traces(textfont_size=12, textangle=0, textposition="outside", cliponaxis=False)
# fig.show()

# x=non_dupl['Group'].unique()
# y=non_dupl['Group'].value_counts()

# print(len(x))
# print(len(y))

# fig = px.bar(x=x, y=y, text_auto='.2s',
#             title="Controlled text sizes, positions and angles")
# fig.update_traces(textfont_size=12, textangle=0, textposition="outside", cliponaxis=False)
# fig.show()

# cnt_asgn_grps = non_dupl['Group'].value_counts()

# cnt_asgn_grps.plot(kind='bar', figsize=(20, 6))
# plt.show()
# len(cnt_asgn_grps)

# %%
cnt_asgn_grps[:25]
# Out:
# IN.AppsMgmt.SAP.FIN-FI              2660
# IN.AppsMgmt.SAP.LOG-SD              1629
# IN.AppsMgmt.SAP.BASIS.AUTH          1515
# IN.AppsMgmt.SAP.LOG-MM              1479
# IN.AppsMgmt.SAP.BASIS               1177
# RU.AppsMgmt.SAP.LOG-SD               887
# IN.AppsMgmt.SAP.FIN-CO               665
# IN.AppsMgmt.SAP.LOG-CS               602
# RU.AppsMgmt.SAP.HRM                  542
# ZZ.ServiceDesk.ATF2.TransferSNOW     512
# IN.AppsMgmt.SAP.AA-FIN-FI            349
# RU.AppsMgmt.SAP.LOG-MM               342
# IN.AppsMgmt.SAP.AA-LOG-SD            329
# RU.AppsMgmt.SAP.FIN-FI               319
# IN.AppsMgmt.SAP.HRM                  303
# IN.AppsMgmt.SAP.LOG-PS               302
# IN.AppsMgmt.SAP.AA-LOG-MM            281
# RU.AppsMgmt.SAP.Interfaces           229
# IN.AppsMgmt.SAP.BASIS.ABAP           210
# CN.AppsMgmt.SAP.LOG-MM               209
# CN.AppsMgmt.SAP.FIN-FI               202
# IN.AppsMgmt.SAP.AA-LOG-CS            189
# IN.AppsMgmt.SAP.AA-BASIS.AUTH        183
# IN.AppsMgmt.SAP.AA-FIN-CO            166
# RU.AppsMgmt.SAP.LOG-PLM              147
# Name: Group, dtype: int64

# %%
valid_labels = cnt_asgn_grps[:25]

# %%
# How much percentage of dataset used by top class group

# %%
cnt_asgn_grps.min(), cnt_asgn_grps.max()
# Out:
# (1, 2660)

# %%
# counts = sorted(cnt_asgn_grps, reverse=True)
# len([f for f in counts if f >100])

# %%
# cnts = non_dupl['Group'].value_counts()
# valid_labels=cnts[cnts >= 40]
# len(valid_labels)

# %%
test_df = non_dupl[non_dupl['Group'].isin(valid_labels.index.to_list())]

# %%
test_df['Group'].value_counts().plot(kind='bar', figsize=(20, 6))
plt.show()

# %%
max_class = test_df[test_df['Group']=='IN.AppsMgmt.SAP.FIN-FI']

# %%
max_class = max_class.sample(1350)

# %%
test_df = test_df[~test_df['Group'].isin(['IN.AppsMgmt.SAP.FIN-FI'])]
test_df = test_df[~test_df['Group'].isin(['ZZ.ServiceDesk.ATF2.TransferSNOW'])]

# %%
test_df = test_df.append(max_class)
test_df = test_df.sample(frac=1)

# %%
test_df['Group'].value_counts().plot(kind='bar', figsize=(20, 6))
plt.show()

# %%
test_df['Short Description'].isna().sum()
# Out:
# 0

# %%
test_df.shape
# Out:
# (13606, 3)

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13606 entries, 134 to 5289
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Short Description  13606 non-null  object
#  1   Description        13606 non-null  object
#  2   Group              13606 non-null  object
# dtypes: object(3)
# memory usage: 425.2+ KB

# %%
#test_df.dropna(subset = ['Short Description'], inplace=True)

# %%
#test_df.shape

# %%
print(valid_labels)
# Out:
# IN.AppsMgmt.SAP.FIN-FI              2660
# IN.AppsMgmt.SAP.LOG-SD              1629
# IN.AppsMgmt.SAP.BASIS.AUTH          1515
# IN.AppsMgmt.SAP.LOG-MM              1479
# IN.AppsMgmt.SAP.BASIS               1177
# RU.AppsMgmt.SAP.LOG-SD               887
# IN.AppsMgmt.SAP.FIN-CO               665
# IN.AppsMgmt.SAP.LOG-CS               602
# RU.AppsMgmt.SAP.HRM                  542
# ZZ.ServiceDesk.ATF2.TransferSNOW     512
# IN.AppsMgmt.SAP.AA-FIN-FI            349
# RU.AppsMgmt.SAP.LOG-MM               342
# IN.AppsMgmt.SAP.AA-LOG-SD            329
# RU.AppsMgmt.SAP.FIN-FI               319
# IN.AppsMgmt.SAP.HRM                  303
# IN.AppsMgmt.SAP.LOG-PS               302
# IN.AppsMgmt.SAP.AA-LOG-MM            281
# RU.AppsMgmt.SAP.Interfaces           229
# IN.AppsMgmt.SAP.BASIS.ABAP           210
# CN.AppsMgmt.SAP.LOG-MM               209
# CN.AppsMgmt.SAP.FIN-FI               202
# IN.AppsMgmt.SAP.AA-LOG-CS            189
# IN.AppsMgmt.SAP.AA-BASIS.AUTH        183
# IN.AppsMgmt.SAP.AA-FIN-CO            166
# RU.AppsMgmt.SAP.LOG-PLM              147
# Name: Group, dtype: int64

# %%
from decimal import Decimal
top25 = test_df.shape[0]
total = non_dupl.shape[0]
percent = round((top25/total)*100, 2)

print(f'Out of {total} non duplicated dataset, we used {top25} top class dataset.\
 It means we worked on {percent}% of top class dataset.')
# Out:
# Out of 17607 non duplicated dataset, we used 13606 top class dataset. It means we worked on 77.28% of top class dataset.

# %%
test_df['Description']=test_df['Short Description'].astype(str)+test_df['Description']

# %%
from bs4 import BeautifulSoup

# https://gist.github.com/sebleier/554280
# we are removing the words from the stop words list: 'no', 'nor', 'not'
# <br /><br /> ==> after the above steps, we are getting "br br"
# we are including them into stop words list
# instead of <br /> if we have <br/> these tags would have revmoved in the 1st step

stopwords= set(['br', 'the', 'i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've","you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself','she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their','theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those','am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does','did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of','at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after','above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further','then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more','most', 'other', 'some', 'such', 'only', 'own', 'same', 'so', 'than', 'too', 'very','s', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're','ve', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn',"hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn',"mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't",'won', "won't", 'wouldn', "wouldn't"])

def decontracted(phrase):
    # specific
    phrase = re.sub(r"won't", "will not", phrase)
    phrase = re.sub(r"can\'t", "can not", phrase)

    # general
    phrase = re.sub(r"n\'t", " not", phrase)
    phrase = re.sub(r"\'re", " are", phrase)
    phrase = re.sub(r"\'s", " is", phrase)
    phrase = re.sub(r"\'d", " would", phrase)
    phrase = re.sub(r"\'ll", " will", phrase)
    phrase = re.sub(r"\'t", " not", phrase)
    phrase = re.sub(r"\'ve", " have", phrase)
    phrase = re.sub(r"\'m", " am", phrase)
    return phrase

print("Data Pre-Processing")
preprocessed_descriptions = []
# tqdm is for printing the status bar
for sentance in tqdm(test_df['Description'].values):
#     sent = sentance.split("-- Original Text --")
#     sentance = sent[0]
#     sentance = re.sub("-- Translated from ([A-Za-z ]*) --","", sentance)
    sentance = re.sub("(\\W)+"," ",sentance)
    sentance = re.sub(r"http\S+", "", sentance)
    sentance = BeautifulSoup(sentance, 'lxml').get_text()
    sentance = decontracted(sentance)
    sentance = re.sub("\S*\d\S*", "", sentance).strip()
    sentance = re.sub('[^A-Za-z]+', ' ', sentance)
    # https://gist.github.com/sebleier/554280
    sentance = ' '.join(e.lower() for e in sentance.split() if e.lower() not in stopwords)
    preprocessed_descriptions.append(sentance.strip())
test_df['Description'] = preprocessed_descriptions
# Out:
# Data Pre-Processing
# 100%|██████████████████████████████████████████████████████████████████████████| 13606/13606 [00:11<00:00, 1179.35it/s]

# %%
test_df.head()
# Out:
#                                       Short Description  \
# 134   Multiple OBS Log communication mail received i...
# 975   SAP: unable to download documents. | Original ...
# 86                    Issues with opening DPR documents
# 784   ¿ ¿¿¿¿¿¿¿¿¿ ¿¿¿¿ ¿ ¿¿¿¿¿¿ ¿¿¿¿ ¿¿¿¿¿¿¿ ¿¿¿¿¿¿¿...
# 1176  Problems with cross-company posting for invoic...
#
#                                             Description  \
# 134   multiple obs log communication mail received i...
# 975   sap unable download documents original text sa...
# 86    issues opening dpr documents dear sir madam is...
# 784       drynova siemens gas power llc callback number
# 1176  problems cross company posting invoices ooo si...
#
#                           Group
# 134   IN.AppsMgmt.SAP.AA-LOG-SD
# 975      IN.AppsMgmt.SAP.LOG-SD
# 86        IN.AppsMgmt.SAP.BASIS
# 784      RU.AppsMgmt.SAP.LOG-SD
# 1176     RU.AppsMgmt.SAP.FIN-FI

# %%
new_df=test_df[['Description','Group']]
new_df.head()
# Out:
#                                             Description  \
# 134   multiple obs log communication mail received i...
# 975   sap unable download documents original text sa...
# 86    issues opening dpr documents dear sir madam is...
# 784       drynova siemens gas power llc callback number
# 1176  problems cross company posting invoices ooo si...
#
#                           Group
# 134   IN.AppsMgmt.SAP.AA-LOG-SD
# 975      IN.AppsMgmt.SAP.LOG-SD
# 86        IN.AppsMgmt.SAP.BASIS
# 784      RU.AppsMgmt.SAP.LOG-SD
# 1176     RU.AppsMgmt.SAP.FIN-FI

# %%
new_df.to_csv('new_balanced_data_50_preprocessed10.csv', index=False)

# %%
df = pd.read_csv('new_balanced_data_50_preprocessed10.csv')

# %%
df.dropna(subset = ['Description'], inplace=True)

# %%
df['Description'] = df['Description'][df['Description'].apply(lambda x: len(x.split()) > 2) == True]

# %%
df['Description'].isna().sum()
# Out:
# 3

# %%
df.dropna(subset = ['Description'], inplace=True)
df.shape
# Out:
# (13598, 2)

# %%
text = ' '.join(df['Description'])

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
# %matplotlib inline
# Create and generate a word cloud image:
wordcloud = WordCloud(width=600,height=300,max_font_size=50, max_words=100).generate(text)

# Display the generated image:
plt.figure(figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
from sklearn.model_selection import train_test_split
BALANCING="ROS"
print("Balancing Techinque :"+BALANCING)
#print("Train-Test Split "+str((1-TESTSIZE)*100)+":"+str(TESTSIZE*100))
if BALANCING=="SMOTE" or BALANCING=="RUS":
    X_train, X_test, y_train, y_test = train_test_split(df, 
                                                    df['Group'], 
                                                    test_size=0.20, 
                                                    random_state=42)
if BALANCING=="ROS":
    X_train, X_test, y_train, y_test = train_test_split(df['Description'], 
                                                    df['Group'], 
                                                    test_size=0.20, 
                                                    random_state=42)

print("Training data points :"+str(len(X_train)))
print("Testing data points :"+str(len(X_test)))
# Out:
# Balancing Techinque :ROS
# Training data points :10878
# Testing data points :2720

# %%
from imblearn.under_sampling import RandomUnderSampler
TEXT_COLUMN_PROCESSED='Description'
# transform the dataset
if BALANCING=="ROS":
    oversample = RandomOverSampler()
    tf_idf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 3), stop_words=stopwords)
    X_train1 = tf_idf.fit_transform(X_train)
    X, y = oversample.fit_resample(X_train1, y_train.ravel())

if BALANCING=="SMOTE":
    oversample = SMOTE()
    tf_idf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1,3), stop_words='english')
    X_train1 = tf_idf.fit_transform(X_train[TEXT_COLUMN_PROCESSED])
    X, y = oversample.fit_resample(X_train1, y_train.ravel())

if BALANCING=="RUS":
    rus = RandomUnderSampler()
    tf_idf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 3), stop_words=stopwords)
    X_train1 = tf_idf.fit_transform(X_train[TEXT_COLUMN_PROCESSED]).toarray()
    X, y = rus.fit_resample(X_train1, y_train.ravel())

# %%
print("Selecting Best Model")
models = [
    RandomForestClassifier(n_estimators=100, max_depth=5, random_state=0,n_jobs=-1),
    LinearSVC(),
    MultinomialNB(),
    LogisticRegression(random_state=0,n_jobs=-1),
    ExtraTreesClassifier(n_estimators=100, random_state=0,n_jobs=-1)
]

# 5 Cross-validation
CV = 5
cv_df = pd.DataFrame(index=range(CV * len(models)))

entries = []
model_names=[]
for model in tqdm(models):
    model_name = model.__class__.__name__
    model_names.append(model_name)
    accuracies = cross_val_score(model, X, y, scoring='accuracy', cv=CV)
    for fold_idx, accuracy in enumerate(accuracies):
        entries.append((model_name, fold_idx, accuracy))

cv_df = pd.DataFrame(entries, columns=['model_name', 'fold_idx', 'accuracy'])
# Out:
# Selecting Best Model
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [05:24<00:00, 64.88s/it]

# %%
mean_accuracy = cv_df.groupby('model_name').accuracy.mean()
std_accuracy = cv_df.groupby('model_name').accuracy.std()

acc = pd.concat([mean_accuracy, std_accuracy], axis= 1, 
        ignore_index=True)
acc.columns = ['Mean Accuracy', 'Standard deviation']

# %%
print("Best Model Selected {}".format(acc['Mean Accuracy'].idxmax()))
model = models[model_names.index(acc['Mean Accuracy'].idxmax())]
# model = LogisticRegression(random_state=0,n_jobs=-1)
model.fit(X, y)
if BALANCING=="SMOTE" or BALANCING=="RUS":
    test_features = tf_idf.transform(X_test[TEXT_COLUMN_PROCESSED]).toarray()
if BALANCING=="ROS":
    test_features = tf_idf.transform(X_test).toarray()
print("Predicting on Test data")
y_pred = model.predict(test_features)
# Out:
# Best Model Selected ExtraTreesClassifier
# Predicting on Test data

# %%
print('\t\t\t\tCLASSIFICATIION METRICS\n')
print(metrics.classification_report(y_test, y_pred, target_names= y_test.unique()))
# Out:
# 				CLASSIFICATIION METRICS
#
#                                precision    recall  f1-score   support
#
#        CN.AppsMgmt.SAP.LOG-MM       0.73      0.97      0.84        39
#        IN.AppsMgmt.SAP.LOG-CS       0.97      0.79      0.87        48
#        IN.AppsMgmt.SAP.LOG-SD       0.67      0.40      0.50        30
#        IN.AppsMgmt.SAP.FIN-FI       0.85      0.42      0.57        40
#     IN.AppsMgmt.SAP.AA-FIN-CO       0.65      0.57      0.60        74
#    IN.AppsMgmt.SAP.BASIS.ABAP       0.58      0.64      0.61        39
#        RU.AppsMgmt.SAP.LOG-SD       0.63      0.49      0.55        53
#        IN.AppsMgmt.SAP.LOG-MM       0.55      0.60      0.58        63
#    IN.AppsMgmt.SAP.BASIS.AUTH       0.70      0.64      0.67       218
#           RU.AppsMgmt.SAP.HRM       0.77      0.59      0.67        41
#     IN.AppsMgmt.SAP.AA-FIN-FI       0.82      0.78      0.80       306
#     IN.AppsMgmt.SAP.AA-LOG-CS       0.74      0.59      0.66       115
#        RU.AppsMgmt.SAP.FIN-FI       0.56      0.62      0.59       279
#     IN.AppsMgmt.SAP.AA-LOG-MM       0.80      0.63      0.71        63
#     IN.AppsMgmt.SAP.AA-LOG-SD       0.67      0.72      0.70       118
#         IN.AppsMgmt.SAP.BASIS       0.71      0.65      0.68       329
#        IN.AppsMgmt.SAP.FIN-CO       0.71      0.69      0.70        58
#        CN.AppsMgmt.SAP.FIN-FI       0.54      0.75      0.63       314
# IN.AppsMgmt.SAP.AA-BASIS.AUTH       0.63      0.38      0.48        63
#           IN.AppsMgmt.SAP.HRM       0.84      0.81      0.83       108
#        IN.AppsMgmt.SAP.LOG-PS       0.74      0.48      0.58        52
#    RU.AppsMgmt.SAP.Interfaces       0.46      0.48      0.47        54
#       RU.AppsMgmt.SAP.LOG-PLM       0.88      0.86      0.87        35
#        RU.AppsMgmt.SAP.LOG-MM       0.64      0.77      0.70       181
#
#                      accuracy                           0.67      2720
#                     macro avg       0.70      0.64      0.66      2720
#                  weighted avg       0.68      0.67      0.67      2720

# %%
pwd
# Out:
# 'C:\\Users\\a854649\\workspace\\ticket-triaging-siemens\\research'

# %%
import pickle
import os
OUT_MODEL_NAME="automated_model1.pkl"
OUT_VEC_NAME="automated_tfidf1.pkl"
OUTDIR="C:\\Users\\a854649\\workspace\\ticket-training\\updated\\ticket-triaging-siemens\\models\\"
print("Saving Model")
if OUTDIR!="":
    pickle.dump(model, open(os.path.join(OUTDIR,OUT_MODEL_NAME), 'wb'))

    pickle.dump(tf_idf, open(os.path.join(OUTDIR,OUT_VEC_NAME), 'wb'))
else:
    pickle.dump(model, open(OUT_MODEL_NAME, 'wb'))

    pickle.dump(tf_idf, open(OUT_VEC_NAME, 'wb'))
print("Model Saved")
# Out:
# Saving Model
# Model Saved

# %%
desc = "Cannot access https://pd.siemens.com.sg/ (KOFAX FINANCE DIRECTOR) using my PKI , Cannot access https://pd.siemens.com.sg/ (KOFAX FINANCE DIRECTOR) using my PKI Error Message: 403 - Forbidden: Access is denied.You do not have permission to view this directory or page using the credentials that you supplied. Callback Number :"
print("Data Pre-Processing")
sentance = desc
# tqdm is for printing the status bar
sentance = re.sub("(\\W)+"," ",sentance)
sentance = re.sub(r"http\S+", "", sentance)
sentance = BeautifulSoup(sentance, 'lxml').get_text()
sentance = decontracted(sentance)
sentance = re.sub("\S*\d\S*", "", sentance).strip()
sentance = re.sub('[^A-Za-z]+', ' ', sentance)
# https://gist.github.com/sebleier/554280
sentance = ' '.join(e.lower() for e in sentance.split() if e.lower() not in stopwords)
sentance = sentance.strip()
print(sentance)
# Out:
# Data Pre-Processing
# cannot access pd siemens com sg kofax finance director using pki cannot access pd siemens com sg kofax finance director using pki error message forbidden access denied not permission view directory page using credentials supplied callback number

# %%
test_features = tf_idf.transform([sentance]).toarray()
y_pred = model.predict(test_features)
print(desc+" => "+y_pred[0])
# Out:
# Cannot access https://pd.siemens.com.sg/ (KOFAX FINANCE DIRECTOR) using my PKI , Cannot access https://pd.siemens.com.sg/ (KOFAX FINANCE DIRECTOR) using my PKI Error Message: 403 - Forbidden: Access is denied.You do not have permission to view this directory or page using the credentials that you supplied. Callback Number : => IN.AppsMgmt.SAP.BASIS.AUTH
